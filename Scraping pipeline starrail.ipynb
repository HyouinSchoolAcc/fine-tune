# %%
import requests
from bs4 import BeautifulSoup

def scrape_dialogue_and_descriptions(url):
    # Send a GET request to the webpage
    response = requests.get(url)
    
    # Parse the page content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Container to store all sections in their original order
    combined_content = []
    
    # Find all dialogue, description, and srmsg-container sections in the page, preserving order
    all_sections = soup.find_all(['div'], class_=['dialogue', 'srw-description-content', 'srmsg-container'])
    
    if not all_sections:
        print("No dialogue or description sections found.")
        return
    
    # Loop through each section (either dialogue, description, or srmsg-container)
    for section in all_sections:
        # Handle srmsg-container sections first (separate logic for message groups)
        if 'srmsg-container' in section.get('class', []):
            dialogues = []
            message_groups = section.find_all('div', class_='srmsg-group')
            for group in message_groups:
                # Extract author and messages
                author_tag = group.find('div', class_='srmsg-author')
                author = author_tag.get_text(strip=True) if author_tag else 'Unknown Author'
                for message_tag in group.find_all('div', class_='srmsg-content'):
                    dialogues.append(f"{author}: {message_tag.get_text(strip=True)}")
            
            # Handle player choices if any
            choices = section.find_all('div', class_='srmsg-choice')
            for choice in choices:
                choice_text = choice.find('div', class_='srmsg-choice-content').get_text(strip=True)
                dialogues.append(f"(Choice: {choice_text})")
                choice_results = choice.find_all('div', class_='srmsg-group-player')
                for result in choice_results:
                    result_author_tag = result.find('div', class_='srmsg-author')
                    result_author = result_author_tag.get_text(strip=True) if result_author_tag else 'Unknown Author'
                    result_message = result.find('div', class_='srmsg-content').get_text(strip=True)
                    dialogues.append(f"{result_author}: {result_message}")
            
            combined_content.append(('srmsg-container', dialogues))
        
        # Handle regular dialogue sections (separate from srmsg-container)
        elif 'dialogue' in section.get('class', []):
            dialogues = []
            for dl in section.find_all('dl'):
                for tag in dl.find_all(['dt', 'dd']):
                    dialogues.append(tag.get_text(strip=True))
            combined_content.append(('dialogue', dialogues))
        
        # Handle description sections
        elif 'srw-description-content' in section.get('class', []):
            description = section.get_text(strip=True)
            combined_content.append(('description', description))
    
    return combined_content

# Example usage
url = "https://honkai-star-rail.fandom.com/wiki/In_the_Dangerous_Muddy_Swamp"
content = scrape_dialogue_and_descriptions(url)

# Print the interwoven dialogues and descriptions
if content:
    for item_type, item_content in content:
        if item_type == 'dialogue':
            print("\n--- Dialogue Section ---")
            for dialogue in item_content:
                print(dialogue)
        elif item_type == 'srmsg-container':
            print("\n--- srmsg Dialogue Section ---")
            for dialogue in item_content:
                print(dialogue)
        elif item_type == 'description':
            print("\n--- Description Section ---")
            print(item_content)
# Out:
# --- Description Section ---
# Cocoliawas defeated and the influence of theStellaronweakened with her demise.Bronyahad fabricated a white lie to let the people ofBelobogaccept the passing of theirSupreme Guardianin battle.Seelethen returned to theOverworldwith Bronya, who was utterly exhausted. At the same time, someone also needs to bring the news of the victory to theUnderworld.
#
# --- Dialogue Section ---
# (Approach theclinic)
# ▶March 7th:Look! There's a big crowd around the clinic.
# ▶March 7th:Do you think they felt the effects of the battle just now...? Let's go ask around.
# (Idle quotes)
# Male Civilian:What was that shaking just now?
# Male Civilian:I thought the whole building was about to collapse...
# Female Civilian:The ground just kept on shaking...
# Female Civilian:Was it theFragmentum?
# (Idle quotes)
# Girl:Was it an earthquake?
# Man:No, it couldn't have been an earthquake...
# Girl:What about an avalanche?
# Man:Eh, not an avalanche either...
# Girl:Then could it be the end of the world?
# Man:Maybe...
# (Idle quotes)
# Elderly Man:It's over, we're doomed...
# Elderly Man:I haven't even written my will yet!
# Elderly Woman:What are you so worked up about?
# Elderly Woman:It's not like we have much to will to anyone in the first place.
# (Approach Natasha)
# ▶March 7th:Natasha!Oleg! Hope you didn't have to wait too long.
# ▶Natasha:Oh! It's them!
# ▶Oleg:You kids move fast! By the look on your faces, I assume you come bearing good news?
# ▶March 7th:Mm-hmm, you bet! You might not believe this, but we summoned up all our strength, and then...
# ▶▶March 7th:...Uh, maybe (Trailblazer) should do the talking. I'm no good at serious stuff — I'll probably say something I'll regret.
# The guardian sacrificed herself to seal the Stellaron.▶Dan Heng:We were there at the fight — we witnessed everything.
# ▶Dan Heng:We were there at the fight — we witnessed everything.
# Do you feel like recounting the story,Dan Heng...?▶Dan Heng:The supreme guardian sacrificed herself to seal the Stellaron. We were there at the fight — we witnessed everything.
# ▶Dan Heng:The supreme guardian sacrificed herself to seal the Stellaron. We were there at the fight — we witnessed everything.
# ▶March 7th:"Sacrificed herself," huh... Sure. Yeah. That's the whole story...
# ▶Natasha:Cocolia? In order to save Belobog, she... I see.
# ▶Oleg:So the massive tremors we felt earlier were a result of the battle, right?
# Yes, it was a hard-won victory.
# We quite literally saved the world...▶March 7th:...Through patting yourself on the back!?
# ▶March 7th:...Through patting yourself on the back!?
# ▶Natasha:...Thank you. I can't even imagine what you've been through up there. I'm just glad everything turned out alright.
# ▶Natasha:What about Seele?
# ▶March 7th:Don't worry, she's alright! It took a big toll on Bronya, so Seele took her over to the Guards.
# ▶Natasha:Good... I'm so glad you're all okay.
# ▶Oleg:Now that Cocolia is no more, I guess ourSilvermane girlis about to become the next supreme guardian?
# ▶Oleg:She sees things through and doesn't go back on her word. TheUnderworldwill thrive again under her watch.
# ▶March 7th:Mm-hmm! Oh, we brought you a message from Bronya! Ahem, "The blockade will soon be lifted. The people of the Underworld will breathe freely."
# ▶Natasha:"Breathe freely..." That's been our wish all along.
# ▶▶Natasha:March, Dan Heng, and (Trailblazer)... can I ask for your help again? I want to get this news out to everyone. It'll lift their spirits and bring them hope.
# Count us in.
# I can't wait to see their faces.
# ▶Natasha:Thank you. Choose whoever you like.Wildfirewill take care of the rest.
# ▶▶March 7th:We've gotten to know a lot of Underworlders... (Trailblazer), who do you think we should start with?
# Let's start with the mining team over at the Great Mine.
# Let's start with Hook and The Moles.
# Let's start with Gertie.
# ▶Natasha:Roger that — you can leave the rest to us. If everything goes smoothly... this should be Wildfire's final mission.
# ▶Dan Heng:We were there at the fight — we witnessed everything.
# ▶Dan Heng:The supreme guardian sacrificed herself to seal the Stellaron. We were there at the fight — we witnessed everything.
# ▶March 7th:...Through patting yourself on the back!?
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.The great tremors from the battle made the Underworlders very concerned. Natasha would like you to to go comfort them and bring the good news to everyone.Go to the Great Mine and see how things are going.
#
# --- Dialogue Section ---
# ▶March 7th:...Do you think the Great Mine was affected by our fighting on the surface?
# ▶Dan Heng:Let's hope we didn't cause a collapse.
# (Reach theVagrant Shelter)
# ▶March 7th:Look, it'sAntonia! The miners and vagrants are all in the same spot.
# ▶March 7th:I sure hope they're not arguing again... Quick, let's head over!
# (Talk to Antonia)
# ▶Antonia:...Here, take it. I'm afraid we're short on goods and materials right now.
# ▶Humble Vagrant:Oh, well we actually have enough for the moment. You hang onto it...
# ▶March 7th:Hey! Are you guys causing trouble again?
# ▶Antonia:It's you! Oh, no, no, you misunderstand...
# ▶Antonia:There was a huge quake at the mine just now — part of it collapsed. If the vagrants here hadn't stopped to help, I doubt we'd have gotten everyone out in one piece.
# ▶Antonia:I was just discussing how to repay them. It's a shame the mining team is hard up right now.
# Wanna hear something really great?▶Antonia:Oh? To do with us? I'm listening...
# ▶Antonia:Oh? To do with us? I'm listening...
# I've got you covered.▶March 7th:Uh... can't we get Bronya to cover the bill?▶▶March 7th:Ugh, can we focus? (Trailblazer), tell them the good news already!
# ▶March 7th:Uh... can't we get Bronya to cover the bill?
# ▶▶March 7th:Ugh, can we focus? (Trailblazer), tell them the good news already!
# Telling the mining team and the vagrants about the victory...
# ▶Antonia:You mean to say that... we're about to be reunited with the Overworld?
# ▶Humble Vagrant:Are you serious!? This has... gotta be a dream. Good things... don't happen to us!
# ▶March 7th:Today they do! And you're not dreaming. If you don't believe us, pinch yourself!
# ▶Antonia:If things go back to the way they were 10 years ago... then the mining team can finally escape this poverty...
# ▶Antonia:...and you won't have to rely on the charity of others. We'll finally be living with the dignity we deserve.
# ▶Humble Vagrant:I... *sniff* *sob*
# Come on. Wipe your tears.
# Let it out!
# ▶Antonia:Thank you, outsiders, from the bottom of my heart! The mining team'll remember you as heroes... as will the rest of the Underworld.
# ▶Antonia:Please tell Natasha that we're ready to get back to work... If the cable car station can start operating again, we'll dispatch a mining representative to negotiate withthe Architects.
# ▶Antonia:Oh? To do with us? I'm listening...
# ▶March 7th:Uh... can't we get Bronya to cover the bill?
# ▶▶March 7th:Ugh, can we focus? (Trailblazer), tell them the good news already!
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.The great tremors from the battle made the Underworlders very concerned. Natasha would like you to to go comfort them and bring the good news to everyone.The kids in the Moles ran to Rivet Town during the commotion. Go check on them.
#
# --- Dialogue Section ---
# ▶Natasha:Those kids better not have taken advantage of the chaos to go on an expedition.
# ▶Natasha:Hookdoes always talk about wanting to go on a Rivet Town adventure... this could be bad.
# (Reach theOrphanage)
# ▶Julian:48... 49... 50!
# ▶Julian:Ready or not, here I come!
# ▶March 7th:...Julian? Quick, let's go see!
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.For Natasha's peace of mind, you arrive at Rivet Town to look for the children who sneaked here to have an adventure.You can hear Julian's voice from far away — They can't be playing hide-and-seek in the Fragmentum, can they...
#
# --- Dialogue Section ---
# (Talk to Julian)
# ▶March 7th:Found you! You ran all the way out here just to play hide-and-seek? It's too dangerous!
# ▶Julian:M—Miss March!? D—Didn't you go back to the surface...?
# ▶March 7th:Since when did I become "Miss" March? And where's Hook and the others? Come on, call them over.
# ▶Julian:Aww... but we just started playing. Can't we finish this round first...?
# Say no more — this is gonna be easy!▶Dan Heng:Seasoned pros, I see...▶March 7th:Hey, it wasn't like I wanted to play! The kids forced us to...
# ▶Dan Heng:Seasoned pros, I see...
# ▶March 7th:Hey, it wasn't like I wanted to play! The kids forced us to...
# If we had lollipops, they'd give themselves up in no time.▶March 7th:Great idea! Shame we don't have any.▶Dan Heng:Well, we better go and find them.
# ▶March 7th:Great idea! Shame we don't have any.
# ▶Dan Heng:Well, we better go and find them.
# ▶Julian:...A—Actually, I sorta wanna go play on the swings for a while... I'll leave the seeking to you guys!
# ▶Dan Heng:Seasoned pros, I see...
# ▶March 7th:Hey, it wasn't like I wanted to play! The kids forced us to...
# ▶March 7th:Great idea! Shame we don't have any.
# ▶Dan Heng:Well, we better go and find them.
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.For Natasha's peace of mind, you arrive at Rivet Town to look for the children who sneaked here to have an adventure.They are actually playing hide-and-seek in the Fragmentum — Go get those naughty kids out of there!
#
# --- Dialogue Section ---
# (FindAlinabehind a chain link fence, optional)
# ▶March 7th:Aha! Gotcha!
# ▶Alina:...Huh? Grown-ups? Where's Julian?
# ▶Alina:Hmph, so he is a scaredy-cat. I knew he'd get someone else to talk to me...
# Well, that explains "sorta wanna go play on the swings for a while..."
# It's not safe here.
# ▶March 7th:You should be happy it's us and not Natasha! If she'd found you, you'd be in big trouble already.
# ▶Alina:Mm... I guess so. Anyway, I'm gonna go find Julian.
# (Find Hook at the side of the building)
# ▶March 7th:Hook! Hehe, got you again!
# ▶Hook:Huh!? Wh—What the heck are you guys doing here? Ugh, wait till I get my hands on Julian, that traitor... Where's his integrity!?
# ▶March 7th:What about your integrity, huh? You brought the other kids out here to Rivet Town, didn't you?
# ▶Hook:I... I did not! The Moles hold a vote on all our expedition destinations!
# Gather your minions, Hook. We've got exciting news!▶Hook:...Fine, I will. But it better be exciting.
# ▶Hook:...Fine, I will. But it better be exciting.
# Maybe we should go and get Natasha...▶Hook:Ah, you snitch! You'll regret it, I'm warning you...
# ▶Hook:Ah, you snitch! You'll regret it, I'm warning you...
# ▶March 7th:Okay, okay, that's enough of that. Let's go and find Julian.(The Moles all gather)
# (The Moles all gather)
# ▶March 7th:Hide-and-seek update... Astral Express crew — 2, The Moles — 0!
# ▶Hook:Hmph, celebrate while you can! Hide-and-seek is best of five, y'know...
# ▶Hook:Anyway, enough about hide-and-seek. You came all this way to tell The Moles something, so spit it out.
# ▶▶March 7th:Hehe... (Trailblazer), do you wanna do the honors?
# Telling The Moles about the victory...
# ▶Hook:...
# ▶Julian:...
# ▶March 7th:Huh? What's wrong? Why aren't you saying anything?
# ▶Alina:Hook, Julian...
# Is our story that scary?
# I wasn't expecting this reaction...
# ▶Julian:*sob*
# ▶Hook:...H—Hey! Wipe your tears, Julian! You're second-in-command — no crying in front of grown-ups!
# ▶Hook:Hmph, you three listen up. Starting from today, you are The Moles' number one rivals!
# ▶March 7th:Rivals...? Why the heck are we rivals now? What are you talking about?
# ▶Alina:...Hook and Julian always wanted to defeat the villains on the surface and take back our homeland.
# ▶Alina:But it sounds like you grown-ups just stole their thunder, so...
# ▶Hook:Hmph! You think we're gonna accept defeat just like that!? One day The Moles will be the heroes of the Underworld and the Overworld! Then everyone will sit... sit...
# Sit up and take notice!
# Sit down and shut up!▶March 7th:...Sit up and take notice, right?
# ▶March 7th:...Sit up and take notice, right?
# ▶Hook:Ah! Yeah — sit up and take notice! I—I would've figured it out myself. I didn't need you to remind me!
# ▶March 7th:So that's why you were so silent! Hmph, if you wanna be as awesome as us, you better start training every day~
# ▶Dan Heng:...And start listening to Natasha.
# ▶Hook:Training every day... listening to the old witch... Will that really make us as awesome as you guys? In that case... deal!
# ▶Hook:Julian, Alina, let's run back to the town! Training starts today!
# ▶Julian:Y—Yes boss! Understood!
# ▶Julian:Uh, Alina, I can... uh... give you a piggyback if you can't make it...
# ▶Hook:...Fine, I will. But it better be exciting.
# ▶Hook:Ah, you snitch! You'll regret it, I'm warning you...
# (The Moles all gather)
# ▶March 7th:...Sit up and take notice, right?
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.The great tremors from the battle made the Underworlders very concerned. Natasha would like you to go confront them and bring the good news to everyone.The Goethe Grand Hotel also seems to be affected. Go see how Gertie is doing.
#
# --- Dialogue Section ---
# ▶March 7th:Why is everyone in such a hurry? I hope nothing's happened at the hotel...
# ▶Dan Heng:We should take a look, maybe we can help.
# (Reach the Goethe Grand Hotel)
# ▶March 7th:I see Gertie! But who's that lying on the ground?
# ▶March 7th:Quick, let's head over!
# (Talk toJoshua)
# ▶Gertie:Oh my, this doesn't look good... Can you hear me? Are you okay?
# ▶Joshua:H—He's still breathing! T—Try not to p—panic Aunt Gertie...
# ▶March 7th:Is everything okay? Wait, isn't that...Peak? Don't tell me he fell asleep in the middle of the road again.
# ▶Gertie:Oh, it's you three! Back in the Underworld so soon?
# ▶Gertie:Word must have gotten out that I was renovating the hotel today. Being the kind-hearted young man that he is, Peak came straight over and offered to help.
# ▶Gertie:There we were hard at work, when all of a sudden the hotel started shaking... I got everyone outside as fast as I could, but I think Peak was hit by a ceiling tile...
# Are you sure he was "hard at work...?"▶March 7th:Look! Seems like he's coming around.
# ▶March 7th:Look! Seems like he's coming around.
# Quick, mouth-to-mouth resuscitation...▶Dan Heng:I... don't think that's necessary. Look, he's awake.(Peak gets up)
# ▶Dan Heng:I... don't think that's necessary. Look, he's awake.
# (Peak gets up)
# ▶Peak:Huh...? Argh...
# ▶Gertie:Peak, are you awake? Oh, thank goodness you're alright! Easy now, take your time...
# ▶Peak:Argh, my back... I was having such a great nap, how did I...
# ▶Joshua:A—Are you okay, bro? L—Let me take you to N—Natasha's clinic...
# ▶March 7th:Hey, look where he was lying. What is that?
# ▶Gertie:It's...
# ▶Gertie:...an old photo. I thought I lost this ages ago. How did it get...
# ▶March 7th:Aunt Gertie, isn't that you in the photo? AndOld Goethe, too! You look so young!
# ▶Gertie:Don't I know it. My distant cousin had only just taken over the family business at the time. He wrote me a letter inviting me to head up and take a look. It's been nearly 20 years already...
# ▶Gertie:*sigh* I remember chatting in the hotel lobby and drinking tea. I wonder if we'll ever get another chance to do that...
# ▶▶March 7th:...Y'know, we've got some good news for you, haven't we, (Trailblazer)?
# You tell Gertie about the victory...
# ▶Gertie:...Is that true? Bronya, she... I—I can't believe my ears!
# Put your faith in Bronya.
# You and Old Goethe will have the kettle on the stove in no time.
# ▶Gertie:I... Hahaha! I don't know what to say! Turns out things aren't always lost forever. *sigh* It feels like better days are finally on the horizon!
# ▶Gertie:Thank you all so much for coming to tell me the good news. I haven't felt like this in a long time... We'll get plenty of guests staying at the hotel again once the passageway is open!
# ▶Gertie:But there's no way I'm letting them set eyes on the old place looking like this... Oh, and we're gonna need to expand the menu. Oh dear. Action stations!
# ▶Peak:Action... stations? Already? Ooh, um — ow, oww...! My head...
# ▶Gertie:Please let Dr. Natasha know not to worry — we're all okay... You three will have to come and stay again once the hotel is fully renovated!
# ▶March 7th:Look! Seems like he's coming around.
# ▶Dan Heng:I... don't think that's necessary. Look, he's awake.
# (Peak gets up)
#
# --- Dialogue Section ---
# MessagesThe Astral Express FamilyWelt@(Trailblazer) @March 7th @Dan Heng, the sealing of the Stellaron is complete, and the spatial distortion is dissipating. Good job.We should be back soon(Trailblazer)We should be back soonWe'll need to stay here a little longer(Trailblazer)We'll need to stay here a little longerWeltDon't rush, go at your own pace. TheExpresswill be here, before you're ready to leave.March 7thGreat!I'm craving some juice... Pom-Pom still owes me a glass!Dan HengHow isJarilo-VI?WeltNot great. Even though the influence of the Stellaron has basically subsided, the existing Fragmentum is too deeply rooted.TheEternal Freezehas lasted a very long time, enough to severely impact the ecology of the planet.In short, the planet probably won't regain the vitality that it once had a thousand years ago in such a short time.March 7thOh... How could this be?Is there anything else we can do?(Trailblazer)Is there anything else we can do?Welt...As Trailblazers, our mission has already concluded successfully. The fate of this world should be handed back to its inhabitants.Humankind has always struggled against austere conditions and had always managed to thrive in spite of it. Now that the Eternal Freeze is gone, the Fragmentum has lost its momentum to expand.Jarilo-VI will be revitalized. Believe in the perseverance of her people.I detected a high-frequency spatial energy surge in the north of Jarilo-VI. You might be interested in checking it out.Don't worry. That energy is not related to the Stellaron. It's only anEcholeft behind after spatial distortions fade away.Inside the Echo, our perceptions of space and time that we are used to will become radically altered, to the point where it might even reconstruct certain scenes from our own past experiences.If you're in the mood and wish to re-live those memorable adventures, you can try your luck at places where Echoes can be found.
# ▶March 7th:...Mr. Yang put it nicely, but the reality is this: We sealed the Stellaron, but that's not gonna solve the problems on this planet...
# ▶March 7th:There I was getting excited to tell everyone the good news...
# We did make a promise...
# We did all we could. Now it's a matter of time...
# Does this count as false advertising?
# ▶Dan Heng:That's the cruelty of a Stellaron. Still, compared with some of the other planets we've visited, at least this one has hope.
# ▶March 7th:So... should we tell everyone the deal?
# ▶Dan Heng:We should tell Bronya when the time's right. Let's not dampen the spirit just yet.
# (UnlockEcho of Warand its Adventure Mission,Echo of War)
#
# --- srmsg Dialogue Section ---
# Welt: @(Trailblazer) @March 7th @Dan Heng, the sealing of the Stellaron is complete, and the spatial distortion is dissipating. Good job.
# (Trailblazer): We should be back soon
# (Trailblazer): We'll need to stay here a little longer
# Welt: Don't rush, go at your own pace. TheExpresswill be here, before you're ready to leave.
# March 7th: Great!
# March 7th: I'm craving some juice... Pom-Pom still owes me a glass!
# Dan Heng: How isJarilo-VI?
# Welt: Not great. Even though the influence of the Stellaron has basically subsided, the existing Fragmentum is too deeply rooted.
# Welt: TheEternal Freezehas lasted a very long time, enough to severely impact the ecology of the planet.
# Welt: In short, the planet probably won't regain the vitality that it once had a thousand years ago in such a short time.
# March 7th: Oh... How could this be?
# (Trailblazer): Is there anything else we can do?
# Welt: ...As Trailblazers, our mission has already concluded successfully. The fate of this world should be handed back to its inhabitants.
# Welt: Humankind has always struggled against austere conditions and had always managed to thrive in spite of it. Now that the Eternal Freeze is gone, the Fragmentum has lost its momentum to expand.
# Welt: Jarilo-VI will be revitalized. Believe in the perseverance of her people.
# Welt: I detected a high-frequency spatial energy surge in the north of Jarilo-VI. You might be interested in checking it out.
# Welt: Don't worry. That energy is not related to the Stellaron. It's only anEcholeft behind after spatial distortions fade away.
# Welt: Inside the Echo, our perceptions of space and time that we are used to will become radically altered, to the point where it might even reconstruct certain scenes from our own past experiences.
# Welt: If you're in the mood and wish to re-live those memorable adventures, you can try your luck at places where Echoes can be found.
# (Choice: We should be back soon)
# (Trailblazer): We should be back soon
# (Choice: We'll need to stay here a little longer)
# (Trailblazer): We'll need to stay here a little longer
# (Choice: Is there anything else we can do?)
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.You passed the news of the victory to the Underworlders and soothed their anxiety.Return to Natasha and report your results... Just remember not to tell anyone about what Welt had sent you, at least for now.
#
# --- Dialogue Section ---
# (Talk to Natasha)
# Doctor Natasha, we're back...
# ▶Natasha:Oh, is everyone alright? Thanks for your help.
# Maybe next time we can send a group notification...▶Natasha:Haha. Sometimes face-to-face communication is more meaningful, don't you think?
# ▶Natasha:Haha. Sometimes face-to-face communication is more meaningful, don't you think?
# For you, anything.▶▶Natasha:I'm flattered, (Trailblazer).
# ▶▶Natasha:I'm flattered, (Trailblazer).
# ▶Natasha:Now we just have to wait for the official news. I hope Bronya doesn't keep us too long.
# ▶March 7th:Huh... do you think Svarog and Clara felt the effects of our battle with the guardian?
# ▶Natasha:I think they'll be fine... Plus Svarog's devotion to Clara is even greater than his hostility to Wildfire. If you're worried, you could look for them over at the robot settlement.
# ▶Natasha:Haha. Sometimes face-to-face communication is more meaningful, don't you think?
# ▶▶Natasha:I'm flattered, (Trailblazer).
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.You passed the news of the victory to the Underworlders. Everyone is happy and celebrating... while you temporarily withhold the ugly truth.There are still two important people not informed of the news, those being Clara and Svarog. Your journey would have been much more difficult without their help.
#
# --- Dialogue Section ---
# (Approach Perkins)
# ▶Perkins:Outssssiders... F—Friends of Clara.
# Hey Perkins!▶March 7th:How did you know that was Perkins...
# ▶March 7th:How did you know that was Perkins...
# Did Clara fix you?
# ▶Perkins:Th—Th—Th—Thank you... for rescuing... Claaaara.
# ▶March 7th:Seems like Perkins picked up a stammer?
# ▶Dan Heng:Its language module must have malfunctioned... Can you take us to Clara?
# ▶Perkins:Outsiders... are f—friends of Clara... Follow me...
# ▶March 7th:How did you know that was Perkins...
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.Your final task in the Underworld is to let Clara and Svarog know about your victory.Follow a restored Perkins to where Clara and Svarog are.
#
# --- Description Section ---
# Cocolia was defeated and the influence of the Stellaron weakened with her demise.Your final task in the Underworld is to let Clara and Svarog know about your victory.These two would likely play important roles in the long journey ahead to rebuild the Underworld.
#
# --- Dialogue Section ---
# (Approach Clara and Svarog)
# ▶Svarog:You have visitors, Clara.
# ▶Clara:Ah! It's the variables!
# Another nickname for the collection...
# Nice haircut, Svarog.▶March 7th:Are you trying to start another fight...
# ▶March 7th:Are you trying to start another fight...
# ▶Clara:There was a huge shaking just now coming up through the ground. Mr. Svarog said it... must have been...
# ▶Svarog:Recalculating... Conclusion:Engine of Creation. 97.66% probability.
# Old friend of yours?
# Any other secret weapons you'd like to tell us about...?
# ▶Svarog:The Engine of Creation was an immense construction machine created by the Architects. It was not built to fight.
# ▶March 7th:Well whatever, we won... Thanks to that giant robot, we were finally able to take care of the Stellaron... and Bronya made a promise — the Underworld and the Overworld will soon be reunited.
# ▶March 7th:Which means that you, Svarog — uh... You won't have to worry about preserving the Underworld... for the time being.
# ▶Clara:March, everyone... thank you so much! I wasn't sure you guys would be able to do it, but...
# ▶Clara:But now... Mr. Svarog, what do you say?
# ▶Clara:You guys said you were travelers from other worlds, right? I want to be just like you... One day, I'm gonna go traveling to faraway places and make new friends.
# I know you will.
# Your future is yours to decide!
# ▶Svarog:Calculation result... update. Mission number 0001 — Preserve the Underworld — complete.
# ▶March 7th:Are you trying to start another fight...
# MessagesBronya, Trailblazer, March 7th, Dan Heng's Group ChatBronyaMarch, Dan Heng, (Trailblazer) — Are you seeing this? This android can actually send messages...Your taste in stickers...(Trailblazer)Your taste in stickers...BronyaHm? What's wrong with that picture? I quite like it...The message has been sent(Trailblazer)The message has been sentBronyaThank you for all you've done for BelobogHow do you feel, physically?(Trailblazer)How do you feel, physically?BronyaThanks to Seele, I'm fine nowBronyaThank goodness. I've already given the orders to the Silvermane Guards to immediately lift the blockade between the Overworld and the Underworld. And some people in the Underworld should have already received the noticeAfter closing for more than a decade, the cable car station should finally be reopening soon. If you don't mind, I would like you to come to the Overworld for my succession ceremonyMarch 7thWoohoo! We wouldn't miss it for the universe!We'll be there(Trailblazer)We'll be thereSee you there, hehe(Trailblazer)See you there, heheIf I'm not busy(Trailblazer)If I'm not busyBronyaSee you there then
# ▶March 7th:That's our Bronya — quick as a flash!
# ▶Dan Heng:She certainly moves a lot faster than some people I know...
# ▶March 7th:...If you haven't got anything nice to say right now, zip it!
#
# --- srmsg Dialogue Section ---
# Bronya: March, Dan Heng, (Trailblazer) — Are you seeing this? This android can actually send messages...
# (Trailblazer): Your taste in stickers...
# Bronya: Hm? What's wrong with that picture? I quite like it...
# (Trailblazer): The message has been sent
# Bronya: Thank you for all you've done for Belobog
# (Trailblazer): How do you feel, physically?
# Bronya: Thanks to Seele, I'm fine now
# Bronya: Thank goodness. I've already given the orders to the Silvermane Guards to immediately lift the blockade between the Overworld and the Underworld. And some people in the Underworld should have already received the notice
# Bronya: After closing for more than a decade, the cable car station should finally be reopening soon. If you don't mind, I would like you to come to the Overworld for my succession ceremony
# March 7th: Woohoo! We wouldn't miss it for the universe!
# (Trailblazer): We'll be there
# (Trailblazer): See you there, hehe
# (Trailblazer): If I'm not busy
# Bronya: See you there then
# (Choice: Your taste in stickers...)
# (Trailblazer): Your taste in stickers...
# (Choice: The message has been sent)
# (Trailblazer): The message has been sent
# (Choice: How do you feel, physically?)
# (Trailblazer): How do you feel, physically?
# (Choice: We'll be there)
# (Trailblazer): We'll be there
# (Choice: See you there, hehe)
# (Trailblazer): See you there, hehe
# (Choice: If I'm not busy)
# (Trailblazer): If I'm not busy

# %%
import time
def get_mission_links(main_url):
    # Send a GET request to the main Trailblaze Missions page
    response = requests.get(main_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the section containing the list of missions
    content_div = soup.find('div', {'class': 'mw-parser-output'})
    
    # Initialize a set to store unique mission links
    mission_links = set()
    
    # Iterate through all 'a' tags within the content division
    for a_tag in content_div.find_all('a', href=True):
        href = a_tag['href']
        # Filter for links that lead to mission pages
        if href.startswith('/wiki/') and 'Trailblaze_Mission' not in href:
            full_url = 'https://honkai-star-rail.fandom.com' + href
            mission_links.add(full_url)
    missions_sorted = sorted(mission_links, key=lambda x: x[41])
    return list(missions_sorted)

def scrape_all_missions():
    main_url = 'https://honkai-star-rail.fandom.com/wiki/Trailblaze_Mission'
    mission_links = get_mission_links(main_url)
    
    for url in mission_links:
        print(f"Scraping {url}...")
        #content = scrape_dialogue_and_descriptions(url)
        # Process the content as needed
        #time.sleep(1)  # Be respectful to the server by adding a delay between requests

# Ensure you have your scrape_dialogue_and_descriptions function defined here

scrape_all_missions()
# Out:
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Grand_Cool_Adventure...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Sunset_Rendezvous...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Moment_of_Peace...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Misfortune_of_Survivors...
# Scraping https://honkai-star-rail.fandom.com/wiki/Aeon...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Cleansing_of_Gold...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Walk_Among_the_Tombstones...
# Scraping https://honkai-star-rail.fandom.com/wiki/Amphoreus...
# Scraping https://honkai-star-rail.fandom.com/wiki/All_About_Eve...
# Scraping https://honkai-star-rail.fandom.com/wiki/Adventure_Mission...
# Scraping https://honkai-star-rail.fandom.com/wiki/Astral_Express_Crew...
# Scraping https://honkai-star-rail.fandom.com/wiki/Achievement...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_New_Venture_on_the_Eighth_Dawn...
# Scraping https://honkai-star-rail.fandom.com/wiki/Astral_Express...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Dragon_Gallant,_Its_Ocean_Distant...
# Scraping https://honkai-star-rail.fandom.com/wiki/All_the_Sad_Tales...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Thousand_Bells_at_Dawn...
# Scraping https://honkai-star-rail.fandom.com/wiki/Apocalyptic_Shadow...
# Scraping https://honkai-star-rail.fandom.com/wiki/Amidst_the_Mara-Struck...
# Scraping https://honkai-star-rail.fandom.com/wiki/An_Invitation_Without_Proffer...
# Scraping https://honkai-star-rail.fandom.com/wiki/Assignments...
# Scraping https://honkai-star-rail.fandom.com/wiki/Activities...
# Scraping https://honkai-star-rail.fandom.com/wiki/A_Witch%27s_Scientific_Repose...
# Scraping https://honkai-star-rail.fandom.com/wiki/And_on_the_Eighth_Day...
# Scraping https://honkai-star-rail.fandom.com/wiki/All_Who_Wakes...
# Scraping https://honkai-star-rail.fandom.com/wiki/Bullet_%26_Brain...
# Scraping https://honkai-star-rail.fandom.com/wiki/Beauty_and_Destruction...
# Scraping https://honkai-star-rail.fandom.com/wiki/Bow_Out_At_Moment_of_D%C3%A9but...
# Scraping https://honkai-star-rail.fandom.com/wiki/Cavern_of_Corrosion...
# Scraping https://honkai-star-rail.fandom.com/wiki/Category:Stats...
# Scraping https://honkai-star-rail.fandom.com/wiki/Chaos_in_the_Deep...
# Scraping https://honkai-star-rail.fandom.com/wiki/Category:Species...
# Scraping https://honkai-star-rail.fandom.com/wiki/Companion_Mission...
# Scraping https://honkai-star-rail.fandom.com/wiki/Category:Terminology...
# Scraping https://honkai-star-rail.fandom.com/wiki/Combat...
# Scraping https://honkai-star-rail.fandom.com/wiki/Calyx...
# Scraping https://honkai-star-rail.fandom.com/wiki/Consumables...
# Scraping https://honkai-star-rail.fandom.com/wiki/Character...
# Scraping https://honkai-star-rail.fandom.com/wiki/Cat_Among_Pigeons...
# Scraping https://honkai-star-rail.fandom.com/wiki/Currencies...
# Scraping https://honkai-star-rail.fandom.com/wiki/Cleanse_in_the_Darkness_Outside...
# Scraping https://honkai-star-rail.fandom.com/wiki/Drifting_Between_the_Stars...
# Scraping https://honkai-star-rail.fandom.com/wiki/Daily_Mission...
# Scraping https://honkai-star-rail.fandom.com/wiki/Desolate_Depths_of_Despair...
# Scraping https://honkai-star-rail.fandom.com/wiki/Dragon_Mislay,_Dreams_Astray...
# Scraping https://honkai-star-rail.fandom.com/wiki/Double_Indemnity...
# Scraping https://honkai-star-rail.fandom.com/wiki/Divergent_Universe:_The_Human_Comedy...
# Scraping https://honkai-star-rail.fandom.com/wiki/Devising_Stratagems...
# Scraping https://honkai-star-rail.fandom.com/wiki/Demise_of_Immortality,_Finale_of_Calamity...
# Scraping https://honkai-star-rail.fandom.com/wiki/Domain_of_Excursion...
# Scraping https://honkai-star-rail.fandom.com/wiki/Distant_Travelers,_Listen_to_this_World%27s_Prayer...
# Scraping https://honkai-star-rail.fandom.com/wiki/Enemy/Elite...
# Scraping https://honkai-star-rail.fandom.com/wiki/Enemy/Normal...
# Scraping https://honkai-star-rail.fandom.com/wiki/Enemy/Echo_of_War...
# Scraping https://honkai-star-rail.fandom.com/wiki/Eidolon...
# Scraping https://honkai-star-rail.fandom.com/wiki/Enemy/Boss...
# Scraping https://honkai-star-rail.fandom.com/wiki/Everything_that_Rises_Must_Converge...
# Scraping https://honkai-star-rail.fandom.com/wiki/Equilibrium_Level...
# Scraping https://honkai-star-rail.fandom.com/wiki/Everwinter_Night...
# Scraping https://honkai-star-rail.fandom.com/wiki/Emanator...
# Scraping https://honkai-star-rail.fandom.com/wiki/Enemy...
# Scraping https://honkai-star-rail.fandom.com/wiki/Echo_of_War...
# Scraping https://honkai-star-rail.fandom.com/wiki/Express_Supply_Pass...
# Scraping https://honkai-star-rail.fandom.com/wiki/Eye_of_the_Storm...
# Scraping https://honkai-star-rail.fandom.com/wiki/Event...
# Scraping https://honkai-star-rail.fandom.com/wiki/Faction...
# Scraping https://honkai-star-rail.fandom.com/wiki/Forgotten_Hall...
# Scraping https://honkai-star-rail.fandom.com/wiki/Farewell,_Penacony...
# Scraping https://honkai-star-rail.fandom.com/wiki/Good_Omen,_My_Friend...
# Scraping https://honkai-star-rail.fandom.com/wiki/Game_Systems...
# Scraping https://honkai-star-rail.fandom.com/wiki/Gentleness,_the_Name_of_Nocturne...
# Scraping https://honkai-star-rail.fandom.com/wiki/Hero,_Bear_Thy_Coreflame...
# Scraping https://honkai-star-rail.fandom.com/wiki/Hide-and-seek...
# Scraping https://honkai-star-rail.fandom.com/wiki/Heroic_Saga_of_Flame-Chase...
# Scraping https://honkai-star-rail.fandom.com/wiki/Herta_Space_Station...
# Scraping https://honkai-star-rail.fandom.com/wiki/Heaven_is_a_Place_on_Earth...
# Scraping https://honkai-star-rail.fandom.com/wiki/Herta_Contract...
# Scraping https://honkai-star-rail.fandom.com/wiki/Honkai:_Star_Rail...
# Scraping https://honkai-star-rail.fandom.com/wiki/Humming_Antlers,_Entwined_Horns...
# Scraping https://honkai-star-rail.fandom.com/wiki/In_the_Dangerous_Muddy_Swamp...
# Scraping https://honkai-star-rail.fandom.com/wiki/In_the_Withering_Wintry_Night...
# Scraping https://honkai-star-rail.fandom.com/wiki/Interastral_Peace_Guide/Daily_Training...
# Scraping https://honkai-star-rail.fandom.com/wiki/Interastral_Peace_Guide/Treasures_Lightward...
# Scraping https://honkai-star-rail.fandom.com/wiki/In_the_Sweltering_Morning_Sun...
# Scraping https://honkai-star-rail.fandom.com/wiki/Items...
# Scraping https://honkai-star-rail.fandom.com/wiki/Interastral_Peace_Guide...
# Scraping https://honkai-star-rail.fandom.com/wiki/In_Our_Time...
# Scraping https://honkai-star-rail.fandom.com/wiki/Jarilo-VI...
# Scraping https://honkai-star-rail.fandom.com/wiki/Kremnos,_Cleanse_Thy_Rusted_Blood_(II)...
# Scraping https://honkai-star-rail.fandom.com/wiki/Kremnos,_Cleanse_Thy_Rusted_Blood_(I)...
# Scraping https://honkai-star-rail.fandom.com/wiki/Karmic_Clouds_Faded,_War_Banners_Folded...
# Scraping https://honkai-star-rail.fandom.com/wiki/Lingering_Shadows...
# Scraping https://honkai-star-rail.fandom.com/wiki/Lullaby_of_the_North_Wind...
# Scraping https://honkai-star-rail.fandom.com/wiki/Lore...
# Scraping https://honkai-star-rail.fandom.com/wiki/Light_Cones...
# Scraping https://honkai-star-rail.fandom.com/wiki/Locations...
# Scraping https://honkai-star-rail.fandom.com/wiki/Life_is_But_a_Drifting_Dream...
# Scraping https://honkai-star-rail.fandom.com/wiki/Long_Wait_for_the_Blade%27s_Edge...
# Scraping https://honkai-star-rail.fandom.com/wiki/Lost_Generation...
# Scraping https://honkai-star-rail.fandom.com/wiki/Long_Day%27s_Journey_Into_Night...
# Scraping https://honkai-star-rail.fandom.com/wiki/Lying_in_Rust...
# Scraping https://honkai-star-rail.fandom.com/wiki/Mission...
# Scraping https://honkai-star-rail.fandom.com/wiki/Mission_Type...
# Scraping https://honkai-star-rail.fandom.com/wiki/Missions...
# Scraping https://honkai-star-rail.fandom.com/wiki/Monetization...
# Scraping https://honkai-star-rail.fandom.com/wiki/Night_Veil,_Shroud_the_Silent_Past...
# Scraping https://honkai-star-rail.fandom.com/wiki/Not_Good_with_Farewells...
# Scraping https://honkai-star-rail.fandom.com/wiki/No_Time_for_Me,_My_Friend...
# Scraping https://honkai-star-rail.fandom.com/wiki/New_Friends_Bring_New_Joy...
# Scraping https://honkai-star-rail.fandom.com/wiki/Nameless_Honor...
# Scraping https://honkai-star-rail.fandom.com/wiki/Night_Stars,_Accompany_My_Slumber...
# Scraping https://honkai-star-rail.fandom.com/wiki/Omniscient_Inquiry_of_Arcana...
# Scraping https://honkai-star-rail.fandom.com/wiki/Ones_Fallen_into_the_Abyss...
# Scraping https://honkai-star-rail.fandom.com/wiki/Obsequies_Performed,_A_Long_Road_Ahead...
# Scraping https://honkai-star-rail.fandom.com/wiki/Oneiric_Shard...
# Scraping https://honkai-star-rail.fandom.com/wiki/Oblation_Obtained,_Order_Ordained...
# Scraping https://honkai-star-rail.fandom.com/wiki/Path...
# Scraping https://honkai-star-rail.fandom.com/wiki/Penacony...
# Scraping https://honkai-star-rail.fandom.com/wiki/Progression...
# Scraping https://honkai-star-rail.fandom.com/wiki/Pure_Fiction...
# Scraping https://honkai-star-rail.fandom.com/wiki/Rivers_Run_Without_Return...
# Scraping https://honkai-star-rail.fandom.com/wiki/Roads_to_the_Past_Have_Long_Been_Closed...
# Scraping https://honkai-star-rail.fandom.com/wiki/Readable...
# Scraping https://honkai-star-rail.fandom.com/wiki/Relics...
# Scraping https://honkai-star-rail.fandom.com/wiki/Reality_is_But_Dream%27s_Echo...
# Scraping https://honkai-star-rail.fandom.com/wiki/Stellar_Jade...
# Scraping https://honkai-star-rail.fandom.com/wiki/Sound_of_Farewell_Hums_Reunion...
# Scraping https://honkai-star-rail.fandom.com/wiki/Soldiers_Stay_Silent...
# Scraping https://honkai-star-rail.fandom.com/wiki/Sleepless_Night...
# Scraping https://honkai-star-rail.fandom.com/wiki/Simulated_Universe:_First_Closed_Beta...
# Scraping https://honkai-star-rail.fandom.com/wiki/Silent_Galaxy...
# Scraping https://honkai-star-rail.fandom.com/wiki/Silver_Chariot,_Away_to_that_Blackened_Land...
# Scraping https://honkai-star-rail.fandom.com/wiki/Stars_Spun,_Prescience_Sprung...
# Scraping https://honkai-star-rail.fandom.com/wiki/Stellaron...
# Scraping https://honkai-star-rail.fandom.com/wiki/Simulated_Universe...
# Scraping https://honkai-star-rail.fandom.com/wiki/Simulated_Universe:_Gold_and_Gears...
# Scraping https://honkai-star-rail.fandom.com/wiki/Seabiscuit...
# Scraping https://honkai-star-rail.fandom.com/wiki/Stagnant_Shadow...
# Scraping https://honkai-star-rail.fandom.com/wiki/Simulated_Universe:_Swarm_Disaster...
# Scraping https://honkai-star-rail.fandom.com/wiki/Small_Town_Grotesque...
# Scraping https://honkai-star-rail.fandom.com/wiki/Soundtrack...
# Scraping https://honkai-star-rail.fandom.com/wiki/Stranger_in_a_Strange_Land...
# Scraping https://honkai-star-rail.fandom.com/wiki/Should_One_Awaken_at_Midnight...
# Scraping https://honkai-star-rail.fandom.com/wiki/Scattered_Memories_of_Hooded_Past...
# Scraping https://honkai-star-rail.fandom.com/wiki/Soldier%27s_Pay...
# Scraping https://honkai-star-rail.fandom.com/wiki/Timeline...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Tell-Tale_Heart...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trial_of_Equilibrium:_Part_Four...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Great_Train_Robbery...
# Scraping https://honkai-star-rail.fandom.com/wiki/Typeface...
# Scraping https://honkai-star-rail.fandom.com/wiki/Tales_from_the_Golden_Age...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trailblaze_Level...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Stars_Are_Cold_Toys...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Fool_Always_Rings_Twice...
# Scraping https://honkai-star-rail.fandom.com/wiki/Topclouded_Towerthrust...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Xianzhou_Luofu...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Voyage_Continues...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Knocking_at_Ungodly_Hours...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trial_of_Equilibrium:_Part_One...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Sound_and_the_Fury...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trial_of_Equilibrium:_Part_Six...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Return...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trailblaze_Continuance...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Departed_Will_Return_First...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Dawn_Here......
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Devil_in_Velvet...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trial_of_Equilibrium:_Part_Three...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trace...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Eighth_and_Final_Rule...
# Scraping https://honkai-star-rail.fandom.com/wiki/To_Rot_or_to_Burn...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trial_of_Equilibrium:_Part_Five...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trailblaze_EXP...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Youths_Who_Chase_Dreams...
# Scraping https://honkai-star-rail.fandom.com/wiki/Today_Is_Yesterday%27s_Tomorrow...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Hound_Chases_the_Fox...
# Scraping https://honkai-star-rail.fandom.com/wiki/Travelers_on_a_Winter_Night...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Sun_Also_Rises...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Past_Will_Return_as_an_Avalanche...
# Scraping https://honkai-star-rail.fandom.com/wiki/Type...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Only_Path_to_Tomorrow...
# Scraping https://honkai-star-rail.fandom.com/wiki/Then_Wake_to_Weep...
# Scraping https://honkai-star-rail.fandom.com/wiki/Trial_of_Equilibrium:_Part_Two...
# Scraping https://honkai-star-rail.fandom.com/wiki/Tranquil_Amidst_Turmoil...
# Scraping https://honkai-star-rail.fandom.com/wiki/Through_a_Glass_Darkly...
# Scraping https://honkai-star-rail.fandom.com/wiki/The_Public_Enemy...
# Scraping https://honkai-star-rail.fandom.com/wiki/Universal_Equilibrium...
# Scraping https://honkai-star-rail.fandom.com/wiki/Unconquered...
# Scraping https://honkai-star-rail.fandom.com/wiki/Unattainable_Idol...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_2.3...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_1.3...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_0.70...
# Scraping https://honkai-star-rail.fandom.com/wiki/Voice_of_the_Galaxy...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_0.60...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_1.0...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version/1.0...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_1.2...
# Scraping https://honkai-star-rail.fandom.com/wiki/Voice_Actor...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_2.7...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_2.2...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_2.0...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_3.0...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_2.1...
# Scraping https://honkai-star-rail.fandom.com/wiki/Version_0.90...
# Scraping https://honkai-star-rail.fandom.com/wiki/Windswept_Wanderlust...
# Scraping https://honkai-star-rail.fandom.com/wiki/Warp...
# Scraping https://honkai-star-rail.fandom.com/wiki/When_the_Sacred_Ginmill_Closes...
# Scraping https://honkai-star-rail.fandom.com/wiki/Whodunit...
# Scraping https://honkai-star-rail.fandom.com/wiki/Wood_Sprouts_Anew,_Fate_Tilts_Askew...
# Scraping https://honkai-star-rail.fandom.com/wiki/Why_Do_the_Heathen_Rage%3F...
# Scraping https://honkai-star-rail.fandom.com/wiki/Wasteland,_Hark_Back_Glory_of_Old...
# Scraping https://honkai-star-rail.fandom.com/wiki/You_Can_Run,_But_You_Can%27t_Hide...
# Scraping https://honkai-star-rail.fandom.com/wiki/Young_Guard...
